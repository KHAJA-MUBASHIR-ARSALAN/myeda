# %% [markdown]
# <h1> Missing

# %%
import pandas as pd

# %%
import sys
sys.path.append("..")

from myeda.core.missing import missing_summary, missing_overview, plot_missing, rows_with_missing

# %%
df = pd.read_csv("titanic_dataset.csv")

# %%
missing_summary(df)
# Out:
#           missing_count  missing_percent
# Cabin               687        77.104377
# Age                 177        19.865320
# Embarked              2         0.224467

# %%
missing_overview(df)
# Out:
# {'total_rows': 891,
#  'total_columns': 12,
#  'total_missing_values': 866,
#  'missing_percentage': np.float64(8.099513655069211),
#  'column_with_missing': 3}

# %%
rows_with_missing(df)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
plot_missing(df)

# %% [markdown]
# <h1> Overview

# %%
from myeda.core.overview import dataset_overview

# %%
dataset_overview(df)
# Out:
# {'rows': 891,
#  'columns': 12,
#  'numeric_columns': 7,
#  'categorical_columns': 5,
#  'boolean_columns': 0,
#  'datetime_columns': 0,
#  'duplicate_rows': 0,
#  'duplicate_percentage': np.float64(0.0),
#  'memory_usage_mb': np.float64(0.28)}

# %% [markdown]
# <h1> Statistics

# %%
from myeda.core.statistics import numeric_summary,categorical_summary

# %%
numeric_summary(df)
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max  skewness   kurtosis
# PassengerId  891.0000  0.000000  -1.200000
# Survived       1.0000  0.478523  -1.775005
# Pclass         3.0000 -0.630548  -1.280015
# Age           80.0000  0.389108   0.178274
# SibSp          8.0000  3.695352  17.880420
# Parch          6.0000  2.749117   9.778125
# Fare         512.3292  4.787317  33.398141

# %%
categorical_summary(df)
# Out:
#           unique_values            most_frequent  frequency
# column
# Name                891  Braund, Mr. Owen Harris          1
# Sex                   2                     male        577
# Ticket              681                   347082          7
# Cabin               147                       G6          4
# Embarked              3                        S        644

# %% [markdown]
# <h1> Visualization

# %%
from myeda.viz.visualization import (
    plot_numeric_distribution,
    plot_boxplot,
    plot_categorical_counts,
    plot_correlation_heatmap
)

# %%
plot_numeric_distribution(df, "Age")
plot_boxplot(df, "Fare")
plot_categorical_counts(df, "Sex", top_n=5)
plot_correlation_heatmap(df)

# %% [markdown]
# <h1> How user interact with liberary

# %%
from myeda.report import EDAReport

report = EDAReport(df)
results = report.run()

# %%
display(results)
# Out:
# {'overview': {'rows': 891,
#   'columns': 12,
#   'numeric_columns': 7,
#   'categorical_columns': 5,
#   'boolean_columns': 0,
#   'datetime_columns': 0,
#   'duplicate_rows': 0,
#   'duplicate_percentage': np.float64(0.0),
#   'memory_usage_mb': np.float64(0.28)},
#  'missing': {'overview': {'total_rows': 891,
#    'total_columns': 12,
#    'total_missing_values': 866,
#    'missing_percentage': np.float64(8.099513655069211),
#    'column_with_missing': 3},
#   'summary':           missing_count  missing_percent
#   Cabin               687        77.104377
#   Age                 177        19.865320
#   Embarked              2         0.224467},
#  'statistics': {'numeric':              count        mean         std   min       25%       50%    75%  \
#   PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
#   Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# ...

# %%
report.visualize(
    numeric_column="Age",
    categorical_column="Sex",
    correlation=True
)
